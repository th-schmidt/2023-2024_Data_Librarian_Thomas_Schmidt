# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_theme()

import pandas as pd

df = pd.read_csv("../data/Library_Usage.csv")
df = df[df['Total Checkouts'] < 841]
plt.figure(figsize=(16, 6))
plt = sns.boxplot(y='Total Checkouts', x='Year Patron Registered', data=df, fliersize=0.5, whis=1.5)
plt.get_figure().savefig("boxplots.png")
# Out:
# /var/folders/23/1xsw6wnj7zx686gppgdjd7900000gn/T/ipykernel_33834/922042.py:7: DtypeWarning: Columns (13) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("../data/Library_Usage.csv")
