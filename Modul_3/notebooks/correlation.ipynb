# %%
import seaborn as sns
import pandas as pd
import numpy as np
sns.set()

n = 1000
cor = [-0.99, -0.7, -0.5, -0.2, 0, 0.2, 0.5, 0.7, 0.99]
dat = pd.DataFrame()

for c in cor:
    covmat = np.array((1, c, c, 1)).reshape((2, 2))
    X = np.random.multivariate_normal([0,0], covmat, size=n)
    X = np.hstack((X, np.ones(n).reshape((n,1))*c))
    dat = pd.concat([dat, pd.DataFrame(X, columns=["x", "y", "correlation"])])
    
g = sns.FacetGrid(col="correlation", data=dat, col_wrap=3)
g.map(sns.scatterplot, "x", "y")
g;

# %%
dat
# Out:
#             x         y  correlation
# 0    1.387398 -1.194591        -0.99
# 1    0.063551 -0.121849        -0.99
# 2   -1.168235  1.153531        -0.99
# 3   -2.046397  2.147157        -0.99
# 4   -0.492775  0.462439        -0.99
# ..        ...       ...          ...
# 995  0.177675  0.059401         0.99
# 996 -1.729597 -2.141730         0.99
# 997 -1.984133 -2.022971         0.99
# 998  0.662468  0.710393         0.99
# 999 -0.614853 -0.694879         0.99
#
# [9000 rows x 3 columns]

# %%
g.savefig('./correlation.png')
