# %% [markdown]
# # **Pandas Introduction**
#
# → [Youtube Intro](https://youtu.be/dcqPhpY7tWk)

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### `pd.Series` und `pd.DataFrame`

# %%
x = pd.Series([34, 12, 23, 45])
x
# Out:
# 0    34
# 1    12
# 2    23
# 3    45
# dtype: int64

# %%
x.dtype
# Out:
# dtype('int64')

# %%
data = {'month': ['Jan', 'Feb', 'Mar'],         # Ordinalskala, diskret
        'temp': [-5, 2, 3],                     # Intervallskala, stetig
        'below_zero': [True, False, False]}     # Nominalskala, diskret

df = pd.DataFrame(data)
df
# Out:
#   month  temp  below_zero
# 0   Jan    -5        True
# 1   Feb     2       False
# 2   Mar     3       False

# %%
df.dtypes
# Out:
# month         object
# temp           int64
# below_zero      bool
# dtype: object

# %%
df.loc[len(df)] = ['Apr', 5, False]
df['year'] = 2020
df
# Out:
#   month  temp  below_zero  year
# 0   Jan    -5        True  2020
# 1   Feb     2       False  2020
# 2   Mar     3       False  2020
# 3   Apr     5       False  2020

# %% [markdown]
# ### Daten **einlesen** und **schreiben**

# %%
df = pd.read_csv('../data/Library_Usage.csv')
df.head(2)
# Out:
# /var/folders/23/1xsw6wnj7zx686gppgdjd7900000gn/T/ipykernel_5228/4291112837.py:1: DtypeWarning: Columns (13) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('../data/Library_Usage.csv')
#    Patron Type Code Patron Type Definition  Total Checkouts  Total Renewals  \
# 0                 5                  Staff               53              15
# 1                 5                  Staff              480             378
#
#   Age Range Home Library Code Home Library Definition  \
# 0       NaN                b2                 Bayview
# 1       NaN                e9               Excelsior
#
#   Circulation Active Month  Circulation Active Year Notice Preference Code  \
# 0                      Mar                   2023.0                      z
# 1                      Jun                   2023.0                      z
#
#   Notice Preference Definition  Provided Email Address  \
# 0                        Email                    True
# 1                        Email                    True
#
#    Year Patron Registered Within San Francisco County
# 0                    2003                       False
# 1                    2003                       False

# %%
df.to_json('../data/lib_usage.json')

# %% [markdown]
# ## 2.3 Exkurs: **Datenrundreise**

# %%
df2 = pd.read_csv('../data/Library_Usage_Small.csv')
df2.head(2)
# Out:
#    Patron Type Code Patron Type Definition  Total Checkouts  Total Renewals  \
# 0                 1               Juvenile                0               0
# 1                 2                   Teen                0               0
#
#         Age Range Home Library Code Home Library Definition  \
# 0    0 to 9 years                r3                Richmond
# 1  10 to 19 years                 x                    Main
#
#    Circulation Active Month  Circulation Active Year Notice Preference Code  \
# 0                       NaN                      NaN                      z
# 1                       NaN                      NaN                      z
#
#   Notice Preference Definition  Provided Email Address  \
# 0                        Email                    True
# 1                        Email                    True
#
#    Year Patron Registered  Within San Francisco County
# 0                    2022                         True
# 1                    2022                         True

# %%
df2.to_json('../data/lib_usage_small.json')

# %%
df2 = pd.read_json('../data/lib_usage_small.json')
df2.to_html('../data/lib_usage_small.html')

# %%
df2 = pd.read_html('../data/lib_usage_small.html')
df2
# Out:
# [   Unnamed: 0  Patron Type Code Patron Type Definition  Total Checkouts  \
#  0           0                 1               Juvenile                0
#  1           1                 2                   Teen                0
#  2           2                 0                  Adult                0
#  3           3                 2                   Teen                0
#  4           4                 2                   Teen                0
#  5           5                 2                   Teen                0
#  6           6                 2                   Teen                0
#  7           7                 2                   Teen                0
#  8           8                 0                  Adult                0
#  9           9                 2                   Teen                0
#
#     Total Renewals       Age Range Home Library Code Home Library Definition  \
#  0               0    0 to 9 years                r3                Richmond
#  1               0  10 to 19 years                 x                    Main
#  2               0  35 to 44 years                m4                  Merced
#  3               0  10 to 19 years                 x                    Main
#  4               0  10 to 19 years                b2                 Bayview
#  5               0  10 to 19 years                 x                    Main
#  6               0  10 to 19 years                 x                    Main
#  7               0  10 to 19 years                 x                    Main
#  8               0  35 to 44 years                 x                    Main
#  9               0  10 to 19 years                 x                    Main
#
#     Circulation Active Month  Circulation Active Year Notice Preference Code  \
#  0                       NaN                      NaN                      z
#  1                       NaN                      NaN                      z
#  2                       NaN                      NaN                      z
#  3                       NaN                      NaN                      z
#  4                       NaN                      NaN                      z
#  5                       NaN                      NaN                      z
#  6                       NaN                      NaN                      z
#  7                       NaN                      NaN                      z
#  8                       NaN                      NaN                      z
#  9                       NaN                      NaN                      z
#
#    Notice Preference Definition  Provided Email Address  \
#  0                        Email                    True
#  1                        Email                    True
#  2                        Email                    True
#  3                        Email                    True
#  4                        Email                    True
#  5                        Email                    True
#  6                        Email                    True
#  7                        Email                    True
#  8                        Email                    True
#  9                        Email                    True
#
#     Year Patron Registered  Within San Francisco County
#  0                    2022                         True
#  1                    2022                         True
#  2                    2019                         True
#  3                    2021                         True
#  4                    2013                         True
#  5                    2021                        False
#  6                    2021                        False
#  7                    2021                         True
#  8                    2019                        False
#  9                    2021                        False  ]

# %%
len(df2)
# Out:
# 1

# %%
df2 = df2[0]
df2.head()
# Out:
#    Unnamed: 0  Patron Type Code Patron Type Definition  Total Checkouts  \
# 0           0                 1               Juvenile                0
# 1           1                 2                   Teen                0
# 2           2                 0                  Adult                0
# 3           3                 2                   Teen                0
# 4           4                 2                   Teen                0
#
#    Total Renewals       Age Range Home Library Code Home Library Definition  \
# 0               0    0 to 9 years                r3                Richmond
# 1               0  10 to 19 years                 x                    Main
# 2               0  35 to 44 years                m4                  Merced
# 3               0  10 to 19 years                 x                    Main
# 4               0  10 to 19 years                b2                 Bayview
#
#    Circulation Active Month  Circulation Active Year Notice Preference Code  \
# 0                       NaN                      NaN                      z
# 1                       NaN                      NaN                      z
# 2                       NaN                      NaN                      z
# 3                       NaN                      NaN                      z
# 4                       NaN                      NaN                      z
#
#   Notice Preference Definition  Provided Email Address  \
# 0                        Email                    True
# 1                        Email                    True
# 2                        Email                    True
# 3                        Email                    True
# 4                        Email                    True
#
#    Year Patron Registered  Within San Francisco County
# 0                    2022                         True
# 1                    2022                         True
# 2                    2019                         True
# 3                    2021                         True
# 4                    2013                         True

# %%
df2.to_excel('../data/lib_usage_small.xlsx')

# %%
df2 = pd.read_excel('../data/lib_usage_small.xlsx')
df2.head(2)
# Out:
#    Unnamed: 0.1  Unnamed: 0  Patron Type Code Patron Type Definition  \
# 0             0           0                 1               Juvenile
# 1             1           1                 2                   Teen
#
#    Total Checkouts  Total Renewals       Age Range Home Library Code  \
# 0                0               0    0 to 9 years                r3
# 1                0               0  10 to 19 years                 x
#
#   Home Library Definition  Circulation Active Month  Circulation Active Year  \
# 0                Richmond                       NaN                      NaN
# 1                    Main                       NaN                      NaN
#
#   Notice Preference Code Notice Preference Definition  Provided Email Address  \
# 0                      z                        Email                    True
# 1                      z                        Email                    True
#
#    Year Patron Registered  Within San Francisco County
# 0                    2022                         True
# 1                    2022                         True

# %%
df2.to_csv('../data/lib_usage_small.csv')

# %% [markdown]
# → mehrere unbenannte Spalten, da beim Speichern kein `index=False` Parameter gesetzt wurde

# %% [markdown]
# ## 2.4 Exkurs: **Arbeitsspeicher**

# %%
# !pip install -qqq asitop

# %%
free_ram_in_GB = 3.9
free_bytes = free_ram_in_GB * 1073741824
free_bytes
# Out:
# 4187593113.6

# %%
# Wie viele int64 Werte, also Zahlen, die 8 Byte (=64 Bit) 
# Speicher benötigen, kannst Du damit theoretisch in den 
# Arbeitsspeicher laden?
int64_mem_usage = 8
var_ints = round(free_bytes / int64_mem_usage)
print(f'Max. int64 für {free_ram_in_GB} GB RAM: {var_ints}')
# Out:
# Max. int64 für 3.9 GB RAM: 523449139

# %%
# Wie viele Beobachtungen kann eine Tabelle mit 100 numerischen 
# Variablen damit maximal theoretisch haben, damit Du diese 
# noch bearbeiten kannst?
cols = 100                    # 100 numerische Variablen
max_observations = round(var_ints / cols)
print(f'Max. Beobachtungen (rows) in einem DataFrame mit {cols} colums of dtype(int64): {var_ints}')
# Out:
# Max. Beobachtungen (rows) in einem DataFrame mit 100 colums of dtype(int64): 523449139

# %%
df.memory_usage(deep=True)
# Out:
# Index                                132
# Patron Type Code                 3490320
# Patron Type Definition          23827986
# Total Checkouts                  3490320
# Total Renewals                   3490320
# Age Range                       27450505
# Home Library Code               22111081
# Home Library Definition         24489516
# Circulation Active Month        21896820
# Circulation Active Year          3490320
# Notice Preference Code          21040698
# Notice Preference Definition    22613902
# Provided Email Address            436290
# Year Patron Registered           3490320
# Within San Francisco County     15701612
# dtype: int64

# %%
df.memory_usage()
# Out:
# Index                               132
# Patron Type Code                3490320
# Patron Type Definition          3490320
# Total Checkouts                 3490320
# Total Renewals                  3490320
# Age Range                       3490320
# Home Library Code               3490320
# Home Library Definition         3490320
# Circulation Active Month        3490320
# Circulation Active Year         3490320
# Notice Preference Code          3490320
# Notice Preference Definition    3490320
# Provided Email Address           436290
# Year Patron Registered          3490320
# Within San Francisco County     3490320
# dtype: int64

# %% [markdown]
# ## Auswahl und Erstellung von Spalten

# %%
df = pd.read_csv("../data/Library_Usage.csv")
df.columns.to_list()
# Out:
# /var/folders/23/1xsw6wnj7zx686gppgdjd7900000gn/T/ipykernel_7197/864253082.py:1: DtypeWarning: Columns (13) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("../data/Library_Usage.csv")
# ['Patron Type Code',
#  'Patron Type Definition',
#  'Total Checkouts',
#  'Total Renewals',
#  'Age Range',
#  'Home Library Code',
#  'Home Library Definition',
#  'Circulation Active Month',
#  'Circulation Active Year',
#  'Notice Preference Code',
#  'Notice Preference Definition',
#  'Provided Email Address',
#  'Year Patron Registered',
#  'Within San Francisco County']

# %%
x = df['Total Renewals']
x
# Out:
# 0           15
# 1          378
# 2           33
# 3         2140
# 4         1035
#           ...
# 436285       6
# 436286       0
# 436287       0
# 436288       0
# 436289     101
# Name: Total Renewals, Length: 436290, dtype: int64

# %%
df[['Total Renewals', 'Total Checkouts']]
# Out:
#         Total Renewals  Total Checkouts
# 0                   15               53
# 1                  378              480
# 2                   33               70
# 3                 2140             3934
# 4                 1035             1118
# ...                ...              ...
# 436285               6                2
# 436286               0                3
# 436287               0                6
# 436288               0                4
# 436289             101              309
#
# [436290 rows x 2 columns]

# %%
column_names = ['Total Renewals', 'Total Checkouts'] # auxiliary variable
subset = df[column_names]
subset
# Out:
#         Total Renewals  Total Checkouts
# 0                   15               53
# 1                  378              480
# 2                   33               70
# 3                 2140             3934
# 4                 1035             1118
# ...                ...              ...
# 436285               6                2
# 436286               0                3
# 436287               0                6
# 436288               0                4
# 436289             101              309
#
# [436290 rows x 2 columns]

# %%
df['dummy_variable'] = 5
df.head(2)
# Out:
#    Patron Type Code Patron Type Definition  Total Checkouts  Total Renewals  \
# 0                 5                  Staff               53              15
# 1                 5                  Staff              480             378
#
#   Age Range Home Library Code Home Library Definition  \
# 0       NaN                b2                 Bayview
# 1       NaN                e9               Excelsior
#
#   Circulation Active Month  Circulation Active Year Notice Preference Code  \
# 0                      Mar                   2023.0                      z
# 1                      Jun                   2023.0                      z
#
#   Notice Preference Definition  Provided Email Address  \
# 0                        Email                    True
# 1                        Email                    True
#
#    Year Patron Registered Within San Francisco County  dummy_variable
# 0                    2003                       False               5
# 1                    2003                       False               5

# %% [markdown]
# Bei der Auswahl von Spalten und Zeilen wird **keine Kopie** des DataFrames oder der Series erstellt, sondern nur eine Referenz auf die ursprüngliche Tabelle. Wenn Du Daten in der ursprünglichen Tabelle änderst, so ändert sich auch die Referenz:

# %%
x = df['Total Renewals']
df['Total Renewals'] = 5
x
# Out:
# 0           15
# 1          378
# 2           33
# 3         2140
# 4         1035
#           ...
# 436285       6
# 436286       0
# 436287       0
# 436288       0
# 436289     101
# Name: Total Renewals, Length: 436290, dtype: int64

# %%
x
# Out:
# 0           15
# 1          378
# 2           33
# 3         2140
# 4         1035
#           ...
# 436285       6
# 436286       0
# 436287       0
# 436288       0
# 436289     101
# Name: Total Renewals, Length: 436290, dtype: int64

# %%
df['is_adult'] = df['Patron Type Definition'] == 'Adult'
df['log_renewals'] = np.log(df['Total Renewals'] + 1)
df.head(2)
# Out:
#    Patron Type Code Patron Type Definition  Total Checkouts  Total Renewals  \
# 0                 5                  Staff               53               5
# 1                 5                  Staff              480               5
#
#   Age Range Home Library Code Home Library Definition  \
# 0       NaN                b2                 Bayview
# 1       NaN                e9               Excelsior
#
#   Circulation Active Month  Circulation Active Year Notice Preference Code  \
# 0                      Mar                   2023.0                      z
# 1                      Jun                   2023.0                      z
#
#   Notice Preference Definition  Provided Email Address  \
# 0                        Email                    True
# 1                        Email                    True
#
#    Year Patron Registered Within San Francisco County  dummy_variable  \
# 0                    2003                       False               5
# 1                    2003                       False               5
#
#    is_adult  log_renewals
# 0     False      1.791759
# 1     False      1.791759

# %%
df['Patron Type Definition'].unique()
# Out:
# array(['Staff', 'Welcome', 'Visitor', 'Digital Access Card', 'Juvenile',
#        'Senior', 'Adult', 'Teen', 'Retired Staff', 'Teacher Card',
#        'At User Adult', 'At User Senior', 'At User Welcome',
#        'At User Teen', 'Business', 'Library By Mail', 'At User Juvenile'],
#       dtype=object)

# %%
df[df['is_adult'] == True].head(2)
# Out:
#     Patron Type Code Patron Type Definition  Total Checkouts  Total Renewals  \
# 44                 0                  Adult                4               5
# 48                 0                  Adult               41               5
#
#          Age Range Home Library Code Home Library Definition  \
# 44  25 to 34 years                p1                    Park
# 48  60 to 64 years                m2                  Marina
#
#    Circulation Active Month  Circulation Active Year Notice Preference Code  \
# 44                      Jun                   2021.0                      z
# 48                      Mar                   2023.0                      z
#
#    Notice Preference Definition  Provided Email Address  \
# 44                        Email                    True
# 48                        Email                    True
#
#     Year Patron Registered Within San Francisco County  dummy_variable  \
# 44                    2020                       False               5
# 48                    2022                       False               5
#
#     is_adult  log_renewals
# 44      True      1.791759
# 48      True      1.791759

# %%
df[df['Patron Type Definition'] == 'Adult']
# Out:
#         Patron Type Code Patron Type Definition  Total Checkouts  \
# 44                     0                  Adult                4
# 48                     0                  Adult               41
# 52                     0                  Adult                0
# 53                     0                  Adult              838
# 56                     0                  Adult                5
# ...                  ...                    ...              ...
# 436277                 0                  Adult                2
# 436280                 0                  Adult                0
# 436284                 0                  Adult               69
# 436285                 0                  Adult                2
# 436287                 0                  Adult                6
#
#         Total Renewals       Age Range Home Library Code  \
# 44                   5  25 to 34 years                p1
# 48                   5  60 to 64 years                m2
# 52                   5  45 to 54 years                g6
# 53                   5  55 to 59 years                r3
# 56                   5  20 to 24 years                 x
# ...                ...             ...               ...
# 436277               5  35 to 44 years                 x
# 436280               5  25 to 34 years                 x
# 436284               5  35 to 44 years               yb9
# 436285               5  35 to 44 years               yjj
# 436287               5  60 to 64 years               ylw
#
#        Home Library Definition Circulation Active Month  \
# 44                        Park                      Jun
# 48                      Marina                      Mar
# 52          Golden Gate Valley                      Jan
# 53                    Richmond                      Jun
# 56                        Main                      May
# ...                        ...                      ...
# 436277                    Main                      Apr
# 436280                    Main                      NaN
# 436284              Bookmobile                      Jul
# 436285              Bookmobile                      Oct
# 436287              Bookmobile                      Mar
#
#         Circulation Active Year Notice Preference Code  \
# 44                       2021.0                      z
# 48                       2023.0                      z
# 52                       2023.0                    NaN
# 53                       2023.0                      z
# 56                       2022.0                      z
# ...                         ...                    ...
# 436277                   2022.0                    NaN
# 436280                      NaN                    NaN
# 436284                   2023.0                      z
# 436285                   2022.0                      z
# 436287                   2022.0                      z
#
#        Notice Preference Definition  Provided Email Address  \
# 44                            Email                    True
# 48                            Email                    True
# 52                              NaN                   False
# 53                            Email                    True
# 56                            Email                    True
# ...                             ...                     ...
# 436277                          NaN                   False
# 436280                          NaN                   False
# 436284                        Email                    True
# 436285                        Email                    True
# 436287                        Email                    True
#
#         Year Patron Registered Within San Francisco County  dummy_variable  \
# 44                        2020                       False               5
# 48                        2022                       False               5
# 52                        2023                       False               5
# 53                        2003                       False               5
# 56                        2021                       False               5
# ...                        ...                         ...             ...
# 436277                    2018                         NaN               5
# 436280                    2023                         NaN               5
# 436284                    2003                         NaN               5
# 436285                    2020                         NaN               5
# 436287                    2022                         NaN               5
#
#         is_adult  log_renewals
# 44          True      1.791759
# 48          True      1.791759
# 52          True      1.791759
# 53          True      1.791759
# 56          True      1.791759
# ...          ...           ...
# 436277      True      1.791759
# 436280      True      1.791759
# 436284      True      1.791759
# 436285      True      1.791759
# 436287      True      1.791759
#
# [274682 rows x 17 columns]

# %% [markdown]
# ## 2.5 Fallstudie: **Feature Engineering**

# %%
df.head(2)
# Out:
#    Patron Type Code Patron Type Definition  Total Checkouts  Total Renewals  \
# 0                 5                  Staff               53               5
# 1                 5                  Staff              480               5
#
#   Age Range Home Library Code Home Library Definition  \
# 0       NaN                b2                 Bayview
# 1       NaN                e9               Excelsior
#
#   Circulation Active Month  Circulation Active Year Notice Preference Code  \
# 0                      Mar                   2023.0                      z
# 1                      Jun                   2023.0                      z
#
#   Notice Preference Definition  Provided Email Address  \
# 0                        Email                    True
# 1                        Email                    True
#
#    Year Patron Registered Within San Francisco County  dummy_variable  \
# 0                    2003                       False               5
# 1                    2003                       False               5
#
#    is_adult  log_renewals
# 0     False      1.791759
# 1     False      1.791759

# %%
df.columns.to_list()
# Out:
# ['Patron Type Code',
#  'Patron Type Definition',
#  'Total Checkouts',
#  'Total Renewals',
#  'Age Range',
#  'Home Library Code',
#  'Home Library Definition',
#  'Circulation Active Month',
#  'Circulation Active Year',
#  'Notice Preference Code',
#  'Notice Preference Definition',
#  'Provided Email Address',
#  'Year Patron Registered',
#  'Within San Francisco County',
#  'dummy_variable',
#  'is_adult',
#  'log_renewals']

# %%
df['Circulation Active Year'].dtype
# Out:
# dtype('float64')

# %%
len(df[df['Circulation Active Year'].isna()])
# Out:
# 39513

# %%
df['Circulation Active Year'] = pd.to_numeric(df['Circulation Active Year'], errors='coerce')
df['Circulation Active Year'].dtype
# Out:
# dtype('float64')

# %%
df['Circulation Active Month'].dtype # object
# Out:
# dtype('O')

# %%
df['Circulation Active Month']
# Out:
# 0         Mar
# 1         Jun
# 2         Jan
# 3         Jul
# 4         Jul
#          ...
# 436285    Oct
# 436286    Nov
# 436287    Mar
# 436288    Sep
# 436289    Jul
# Name: Circulation Active Month, Length: 436290, dtype: object

# %%
df['circ_a_month'] = pd.to_datetime(arg=df['Circulation Active Month'],
                                    format='%b',
                                    errors='coerce')

# %%
df['circ_a_month']
# Out:
# 0        1900-03-01
# 1        1900-06-01
# 2        1900-01-01
# 3        1900-07-01
# 4        1900-07-01
#             ...
# 436285   1900-10-01
# 436286   1900-11-01
# 436287   1900-03-01
# 436288   1900-09-01
# 436289   1900-07-01
# Name: circ_a_month, Length: 436290, dtype: datetime64[ns]

# %%
df['circ_a_month'].dt.month
# Out:
# 0          3.0
# 1          6.0
# 2          1.0
# 3          7.0
# 4          7.0
#           ...
# 436285    10.0
# 436286    11.0
# 436287     3.0
# 436288     9.0
# 436289     7.0
# Name: circ_a_month, Length: 436290, dtype: float64

# %%
df.iloc[0:1]
# Out:
#    Patron Type Code Patron Type Definition  Total Checkouts  Total Renewals  \
# 0                 5                  Staff               53               5
#
#   Age Range Home Library Code Home Library Definition  \
# 0       NaN                b2                 Bayview
#
#   Circulation Active Month  Circulation Active Year Notice Preference Code  \
# 0                      Mar                   2023.0                      z
#
#   Notice Preference Definition  Provided Email Address  \
# 0                        Email                    True
#
#    Year Patron Registered Within San Francisco County  dummy_variable  \
# 0                    2003                       False               5
#
#    is_adult  log_renewals circ_a_month
# 0     False      1.791759   1900-03-01

# %%
df['membership_duration_in_months'] = (df['Circulation Active Year'] - df['Year Patron Registered']) * 12 + df['circ_a_month'].dt.month
df['membership_duration_in_months'] = df['membership_duration_in_months'].fillna(0)

# %%
df.head()
# Out:
#    Patron Type Code Patron Type Definition  Total Checkouts  Total Renewals  \
# 0                 5                  Staff               53               5
# 1                 5                  Staff              480               5
# 2                 5                  Staff               70               5
# 3                 5                  Staff             3934               5
# 4                 5                  Staff             1118               5
#
#         Age Range Home Library Code Home Library Definition  \
# 0             NaN                b2                 Bayview
# 1             NaN                e9               Excelsior
# 2  45 to 54 years                n4              Noe Valley
# 3             NaN                o2              Ocean View
# 4             NaN                o7                  Ortega
#
#   Circulation Active Month  Circulation Active Year Notice Preference Code  \
# 0                      Mar                   2023.0                      z
# 1                      Jun                   2023.0                      z
# 2                      Jan                   2023.0                      z
# 3                      Jul                   2023.0                      z
# 4                      Jul                   2023.0                      z
#
#   Notice Preference Definition  Provided Email Address  \
# 0                        Email                    True
# 1                        Email                    True
# 2                        Email                    True
# 3                        Email                    True
# 4                        Email                    True
#
#    Year Patron Registered Within San Francisco County  dummy_variable  \
# 0                    2003                       False               5
# 1                    2003                       False               5
# 2                    2011                       False               5
# 3                    2003                       False               5
# 4                    2003                       False               5
#
#    is_adult  log_renewals circ_a_month  membership_duration_in_months
# 0     False      1.791759   1900-03-01                          243.0
# 1     False      1.791759   1900-06-01                          246.0
# 2     False      1.791759   1900-01-01                          145.0
# 3     False      1.791759   1900-07-01                          247.0
# 4     False      1.791759   1900-07-01                          247.0

# %%
df.to_csv('../data/lib_usage_enhanced.csv', index=False)

# %% [markdown]
# ## Auswahl von **Zeilen**

# %%
df = pd.read_csv('../data/lib_usage_enhanced.csv')
df.head(2)
# Out:
# /var/folders/23/1xsw6wnj7zx686gppgdjd7900000gn/T/ipykernel_7836/319829161.py:1: DtypeWarning: Columns (13) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('../data/lib_usage_enhanced.csv')
#    Patron Type Code Patron Type Definition  Total Checkouts  Total Renewals  \
# 0                 5                  Staff               53               5
# 1                 5                  Staff              480               5
#
#   Age Range Home Library Code Home Library Definition  \
# 0       NaN                b2                 Bayview
# 1       NaN                e9               Excelsior
#
#   Circulation Active Month  Circulation Active Year Notice Preference Code  \
# 0                      Mar                   2023.0                      z
# 1                      Jun                   2023.0                      z
#
#   Notice Preference Definition  Provided Email Address  \
# 0                        Email                    True
# 1                        Email                    True
#
#    Year Patron Registered Within San Francisco County  dummy_variable  \
# 0                    2003                       False               5
# 1                    2003                       False               5
#
#    is_adult  log_renewals circ_a_month  membership_duration_in_months
# 0     False      1.791759   1900-03-01                          243.0
# 1     False      1.791759   1900-06-01                          246.0

# %%
df.loc[df['Total Checkouts'] > 10000]
# Out:
#         Patron Type Code Patron Type Definition  Total Checkouts  \
# 7946                   3                 Senior            12095
# 11000                  3                 Senior            10386
# 16641                  3                 Senior            12363
# 22331                  0                  Adult            16483
# 23428                  3                 Senior            10080
# ...                  ...                    ...              ...
# 364224                 3                 Senior            10330
# 375195                 0                  Adult            45380
# 385277                 3                 Senior            12149
# 422501                 3                 Senior            15456
# 434124                 3                 Senior            17494
#
#         Total Renewals          Age Range Home Library Code  \
# 7946                 5  75 years and over                m4
# 11000                5  75 years and over                o7
# 16641                5     65 to 74 years                c2
# 22331                5     60 to 64 years                m6
# 23428                5     65 to 74 years                r3
# ...                ...                ...               ...
# 364224               5     65 to 74 years                 x
# 375195               5     35 to 44 years                v3
# 385277               5     65 to 74 years                s7
# 422501               5     65 to 74 years                m2
# 434124               5     65 to 74 years                 x
#
#        Home Library Definition Circulation Active Month  \
# 7946                    Merced                      Jul
# 11000                   Ortega                      Jul
# 16641                Chinatown                      Jul
# 22331                  Mission                      Jul
# 23428                 Richmond                      Jul
# ...                        ...                      ...
# 364224                    Main                      Jul
# 375195       Visitacion Valley                      Dec
# 385277                  Sunset                      Jul
# 422501                  Marina                      Jul
# 434124                    Main                      Jul
#
#         Circulation Active Year Notice Preference Code  \
# 7946                     2023.0                      z
# 11000                    2023.0                      z
# 16641                    2023.0                      z
# 22331                    2023.0                    NaN
# 23428                    2023.0                      z
# ...                         ...                    ...
# 364224                   2023.0                    NaN
# 375195                   2020.0                    NaN
# 385277                   2023.0                      z
# 422501                   2023.0                      z
# 434124                   2023.0                      z
#
#        Notice Preference Definition  Provided Email Address  \
# 7946                          Email                    True
# 11000                         Email                    True
# 16641                         Email                    True
# 22331                           NaN                   False
# 23428                         Email                    True
# ...                             ...                     ...
# 364224                          NaN                   False
# 375195                          NaN                   False
# 385277                        Email                    True
# 422501                        Email                    True
# 434124                        Email                    True
#
#         Year Patron Registered Within San Francisco County  dummy_variable  \
# 7946                      2003                       False               5
# 11000                     2003                       False               5
# 16641                     2003                       False               5
# 22331                     2003                       False               5
# 23428                     2003                       False               5
# ...                        ...                         ...             ...
# 364224                    2003                       False               5
# 375195                    2003                       False               5
# 385277                    2003                       False               5
# 422501                    2008                       False               5
# 434124                    2003                       False               5
#
#         is_adult  log_renewals circ_a_month  membership_duration_in_months
# 7946       False      1.791759   1900-07-01                          247.0
# 11000      False      1.791759   1900-07-01                          247.0
# 16641      False      1.791759   1900-07-01                          247.0
# 22331       True      1.791759   1900-07-01                          247.0
# 23428      False      1.791759   1900-07-01                          247.0
# ...          ...           ...          ...                            ...
# 364224     False      1.791759   1900-07-01                          247.0
# 375195      True      1.791759   1900-12-01                          216.0
# 385277     False      1.791759   1900-07-01                          247.0
# 422501     False      1.791759   1900-07-01                          187.0
# 434124     False      1.791759   1900-07-01                          247.0
#
# [85 rows x 19 columns]

# %% [markdown]
# ### `Series.between(left, right)`

# %%
df.loc[df['Total Checkouts'].between(df['Total Checkouts'].mean(), df['Total Checkouts'].max())]
# Out:
#         Patron Type Code Patron Type Definition  Total Checkouts  \
# 1                      5                  Staff              480
# 3                      5                  Staff             3934
# 4                      5                  Staff             1118
# 5                      5                  Staff             2635
# 6                      5                  Staff              774
# ...                  ...                    ...              ...
# 436196                16    Digital Access Card              270
# 436211                 5                  Staff             2933
# 436225                 5                  Staff              664
# 436260                 0                  Adult              172
# 436289                55          Retired Staff              309
#
#         Total Renewals          Age Range Home Library Code  \
# 1                    5                NaN                e9
# 3                    5                NaN                o2
# 4                    5                NaN                o7
# 5                    5     45 to 54 years                w2
# 6                    5     55 to 59 years                 x
# ...                ...                ...               ...
# 436196               5                NaN                 x
# 436211               5                NaN                 x
# 436225               5                NaN                 x
# 436260               5     60 to 64 years                 x
# 436289               5  75 years and over               ylw
#
#        Home Library Definition Circulation Active Month  \
# 1                    Excelsior                      Jun
# 3                   Ocean View                      Jul
# 4                       Ortega                      Jul
# 5                  West Portal                      Jul
# 6                         Main                      Jul
# ...                        ...                      ...
# 436196                    Main                      Jun
# 436211                    Main                      Jul
# 436225                    Main                      Jul
# 436260                    Main                      Jul
# 436289              Bookmobile                      Jul
#
#         Circulation Active Year Notice Preference Code  \
# 1                        2023.0                      z
# 3                        2023.0                      z
# 4                        2023.0                      z
# 5                        2023.0                      z
# 6                        2023.0                      z
# ...                         ...                    ...
# 436196                   2023.0                      z
# 436211                   2023.0                      z
# 436225                   2023.0                      z
# 436260                   2023.0                    NaN
# 436289                   2023.0                      z
#
#        Notice Preference Definition  Provided Email Address  \
# 1                             Email                    True
# 3                             Email                    True
# 4                             Email                    True
# 5                             Email                    True
# 6                             Email                    True
# ...                             ...                     ...
# 436196                        Email                    True
# 436211                        Email                    True
# 436225                        Email                    True
# 436260                          NaN                   False
# 436289                        Email                    True
#
#         Year Patron Registered Within San Francisco County  dummy_variable  \
# 1                         2003                       False               5
# 3                         2003                       False               5
# 4                         2003                       False               5
# 5                         2003                       False               5
# 6                         2003                       False               5
# ...                        ...                         ...             ...
# 436196                    2017                         NaN               5
# 436211                    2003                         NaN               5
# 436225                    2003                         NaN               5
# 436260                    2022                         NaN               5
# 436289                    2003                         NaN               5
#
#         is_adult  log_renewals circ_a_month  membership_duration_in_months
# 1          False      1.791759   1900-06-01                          246.0
# 3          False      1.791759   1900-07-01                          247.0
# 4          False      1.791759   1900-07-01                          247.0
# 5          False      1.791759   1900-07-01                          247.0
# 6          False      1.791759   1900-07-01                          247.0
# ...          ...           ...          ...                            ...
# 436196     False      1.791759   1900-06-01                           78.0
# 436211     False      1.791759   1900-07-01                          247.0
# 436225     False      1.791759   1900-07-01                          247.0
# 436260      True      1.791759   1900-07-01                           19.0
# 436289     False      1.791759   1900-07-01                          247.0
#
# [78031 rows x 19 columns]

# %% [markdown]
# ### Filtere den Datensatz nach Kindern unter 10 Jahren. Wie viele Einträge erhältst Du?

# %%
df['Age Range'].unique()
# Out:
# array([nan, '45 to 54 years', '55 to 59 years', '60 to 64 years',
#        '25 to 34 years', '35 to 44 years', '20 to 24 years',
#        '75 years and over', '10 to 19 years', '0 to 9 years',
#        '65 to 74 years'], dtype=object)

# %%
len(df[df['Age Range'] == '0 to 9 years'])
# Out:
# 32692

# %% [markdown]
# ### Gibt es Personen mit mehr als 20000 Ausleihen?

# %%
df.loc[df['Total Checkouts'] > 20000]
# Out:
#         Patron Type Code Patron Type Definition  Total Checkouts  \
# 51592                  3                 Senior            22934
# 74783                  3                 Senior            21890
# 95369                  3                 Senior            20411
# 95967                  3                 Senior            20351
# 192830                 0                  Adult            23706
# 198191                 0                  Adult            37249
# 278966                 0                  Adult            33122
# 354659                 0                  Adult            22187
# 375195                 0                  Adult            45380
#
#         Total Renewals          Age Range Home Library Code  \
# 51592                5     65 to 74 years                 x
# 74783                5  75 years and over                 x
# 95369                5     65 to 74 years                 x
# 95967                5     65 to 74 years                 x
# 192830               5     45 to 54 years                c2
# 198191               5     55 to 59 years                o7
# 278966               5     25 to 34 years                s7
# 354659               5     55 to 59 years                c2
# 375195               5     35 to 44 years                v3
#
#        Home Library Definition Circulation Active Month  \
# 51592                     Main                      Jul
# 74783                     Main                      Jan
# 95369                     Main                      Aug
# 95967                     Main                      Jul
# 192830               Chinatown                      Jul
# 198191                  Ortega                      Jul
# 278966                  Sunset                      Jul
# 354659               Chinatown                      Jul
# 375195       Visitacion Valley                      Dec
#
#         Circulation Active Year Notice Preference Code  \
# 51592                    2023.0                    NaN
# 74783                    2023.0                      z
# 95369                    2019.0                    NaN
# 95967                    2023.0                    NaN
# 192830                   2023.0                    NaN
# 198191                   2023.0                      z
# 278966                   2023.0                      z
# 354659                   2023.0                      z
# 375195                   2020.0                    NaN
#
#        Notice Preference Definition  Provided Email Address  \
# 51592                           NaN                   False
# 74783                         Email                    True
# 95369                           NaN                   False
# 95967                           NaN                   False
# 192830                          NaN                   False
# 198191                        Email                    True
# 278966                        Email                    True
# 354659                        Email                    True
# 375195                          NaN                   False
#
#         Year Patron Registered Within San Francisco County  dummy_variable  \
# 51592                     2003                       False               5
# 74783                     2005                       False               5
# 95369                     2003                       False               5
# 95967                     2004                       False               5
# 192830                    2003                       False               5
# 198191                    2003                       False               5
# 278966                    2010                       False               5
# 354659                    2003                       False               5
# 375195                    2003                       False               5
#
#         is_adult  log_renewals circ_a_month  membership_duration_in_months
# 51592      False      1.791759   1900-07-01                          247.0
# 74783      False      1.791759   1900-01-01                          217.0
# 95369      False      1.791759   1900-08-01                          200.0
# 95967      False      1.791759   1900-07-01                          235.0
# 192830      True      1.791759   1900-07-01                          247.0
# 198191      True      1.791759   1900-07-01                          247.0
# 278966      True      1.791759   1900-07-01                          163.0
# 354659      True      1.791759   1900-07-01                          247.0
# 375195      True      1.791759   1900-12-01                          216.0

# %% [markdown]
# ### Wie viele Personen stammen aus dem Stadtteil (Richmond)?

# %%
df[df['Home Library Definition'] == 'Richmond']['Patron Type Code'].count()
# Out:
# 20656

# %%
len(df[df['Home Library Definition'] == 'Richmond'])
# Out:
# 20656

# %% [markdown]
# ### Wie viele Prozent der Beobachtungen haben eine Membership Duration von Null Monaten?

# %%
round(len(df) / len(df[df['membership_duration_in_months'] == 0]), 2)
# Out:
# 11.04

# %% [markdown]
# ## Exkurs: **Fehlende Werte**

# %%
len(df[df['Age Range'].isna()])
# Out:
# 912

# %%
len(df[df['Age Range'].notna()])
# Out:
# 435378

# %%
df.isna().sum()
# Out:
# Patron Type Code                     0
# Patron Type Definition               0
# Total Checkouts                      0
# Total Renewals                       0
# Age Range                          912
# Home Library Code                    2
# Home Library Definition             30
# Circulation Active Month         39513
# Circulation Active Year          39513
# Notice Preference Code           42989
# Notice Preference Definition     42989
# Provided Email Address               0
# Year Patron Registered               0
# Within San Francisco County       1207
# dummy_variable                       0
# is_adult                             0
# log_renewals                         0
# circ_a_month                     39513
# membership_duration_in_months        0
# dtype: int64

# %%
# drops all rows that contain at least one missing values
# df = df.dropna()
# df

# %% [markdown]
# ### 2.8 Exkurs: Fehlende Werte

# %% [markdown]
# #### Welche Spalten enthalten alles fehlende Werte?

# %%
null_cols = df.isna().sum()
null_cols = null_cols[null_cols > 0]
null_cols.index
# Out:
# Index(['Age Range', 'Home Library Code', 'Home Library Definition',
#        'Circulation Active Month', 'Circulation Active Year',
#        'Notice Preference Code', 'Notice Preference Definition',
#        'Within San Francisco County', 'circ_a_month'],
#       dtype='object')

# %% [markdown]
# #### Lies den Datensatz ein und erstelle einen DataFrame der keine Beobachtungen mit fehlenden Werten mehr enthält.

# %%
df_clean = df.dropna()
df_clean
# Out:
#         Patron Type Code Patron Type Definition  Total Checkouts  \
# 2                      5                  Staff               70
# 5                      5                  Staff             2635
# 6                      5                  Staff              774
# 7                      5                  Staff              508
# 9                      5                  Staff              110
# ...                  ...                    ...              ...
# 435078                 0                  Adult                0
# 435079                 3                 Senior                0
# 435080                 3                 Senior                0
# 435081                 3                 Senior                0
# 435082                 0                  Adult                0
#
#         Total Renewals          Age Range Home Library Code  \
# 2                    5     45 to 54 years                n4
# 5                    5     45 to 54 years                w2
# 6                    5     55 to 59 years                 x
# 7                    5     45 to 54 years                 x
# 9                    5     45 to 54 years                 x
# ...                ...                ...               ...
# 435078               5     25 to 34 years                 x
# 435079               5  75 years and over                 x
# 435080               5  75 years and over                 x
# 435081               5     65 to 74 years                 x
# 435082               5     45 to 54 years                e7
#
#        Home Library Definition Circulation Active Month  \
# 2                   Noe Valley                      Jan
# 5                  West Portal                      Jul
# 6                         Main                      Jul
# 7                         Main                      Jul
# 9                         Main                      Mar
# ...                        ...                      ...
# 435078                    Main                      Jul
# 435079                    Main                      Jul
# 435080                    Main                      Nov
# 435081                    Main                      Sep
# 435082           Eureka Valley                      Jul
#
#         Circulation Active Year Notice Preference Code  \
# 2                        2023.0                      z
# 5                        2023.0                      z
# 6                        2023.0                      z
# 7                        2023.0                      z
# 9                        2023.0                      z
# ...                         ...                    ...
# 435078                   2023.0                      z
# 435079                   2023.0                      z
# 435080                   2019.0                      z
# 435081                   2022.0                      z
# 435082                   2023.0                      z
#
#        Notice Preference Definition  Provided Email Address  \
# 2                             Email                    True
# 5                             Email                    True
# 6                             Email                    True
# 7                             Email                    True
# 9                             Email                    True
# ...                             ...                     ...
# 435078                        Email                    True
# 435079                        Email                    True
# 435080                        Email                    True
# 435081                        Email                    True
# 435082                        Email                    True
#
#         Year Patron Registered Within San Francisco County  dummy_variable  \
# 2                         2011                       False               5
# 5                         2003                       False               5
# 6                         2003                       False               5
# 7                         2005                       False               5
# 9                         2016                       False               5
# ...                        ...                         ...             ...
# 435078                    2022                       False               5
# 435079                    2010                       False               5
# 435080                    2008                       False               5
# 435081                    2016                       False               5
# 435082                    2015                       False               5
#
#         is_adult  log_renewals circ_a_month  membership_duration_in_months
# 2          False      1.791759   1900-01-01                          145.0
# 5          False      1.791759   1900-07-01                          247.0
# 6          False      1.791759   1900-07-01                          247.0
# 7          False      1.791759   1900-07-01                          223.0
# 9          False      1.791759   1900-03-01                           87.0
# ...          ...           ...          ...                            ...
# 435078      True      1.791759   1900-07-01                           19.0
# 435079     False      1.791759   1900-07-01                          163.0
# 435080     False      1.791759   1900-11-01                          143.0
# 435081     False      1.791759   1900-09-01                           81.0
# 435082      True      1.791759   1900-07-01                          103.0
#
# [357838 rows x 19 columns]

# %% [markdown]
# #### Speichere diesen unter dem Namen

# %%
df_clean.to_csv('../data/Library_Usage_Clean.csv', index=False)

# %% [markdown]
# #### Wie viele Beobachtungen wurden dabei entfernt?

# %%
len(df) - len(df_clean)
# Out:
# 78452

# %% [markdown]
# ## Nützliche Funktionen in Pandas

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 436290 entries, 0 to 436289
# Data columns (total 19 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   Patron Type Code               436290 non-null  int64
#  1   Patron Type Definition         436290 non-null  object
#  2   Total Checkouts                436290 non-null  int64
#  3   Total Renewals                 436290 non-null  int64
#  4   Age Range                      435378 non-null  object
#  5   Home Library Code              436288 non-null  object
#  6   Home Library Definition        436260 non-null  object
#  7   Circulation Active Month       396777 non-null  object
#  8   Circulation Active Year        396777 non-null  float64
#  9   Notice Preference Code         393301 non-null  object
#  10  Notice Preference Definition   393301 non-null  object
#  11  Provided Email Address         436290 non-null  bool
#  12  Year Patron Registered         436290 non-null  int64
#  13  Within San Francisco County    435083 non-null  object
#  14  dummy_variable                 436290 non-null  int64
#  15  is_adult                       436290 non-null  bool
#  16  log_renewals                   436290 non-null  float64
#  17  circ_a_month                   396777 non-null  object
#  18  membership_duration_in_months  436290 non-null  float64
# dtypes: bool(2), float64(3), int64(5), object(9)
# memory usage: 57.4+ MB

# %%
df.describe()
# Out:
#        Patron Type Code  Total Checkouts  Total Renewals  \
# count     436290.000000    436290.000000        436290.0
# mean           1.081295       160.294843             5.0
# std            3.383103       537.923680             0.0
# min            0.000000         0.000000             5.0
# 25%            0.000000         0.000000             5.0
# 50%            0.000000         7.000000             5.0
# 75%            1.000000        78.000000             5.0
# max          104.000000     45380.000000             5.0
#
#        Circulation Active Year  Year Patron Registered  dummy_variable  \
# count            396777.000000           436290.000000        436290.0
# mean               2022.170698             2015.598327             5.0
# std                   1.358145                6.148953             0.0
# min                2004.000000             2003.000000             5.0
# 25%                2022.000000             2012.000000             5.0
# 50%                2023.000000             2017.000000             5.0
# 75%                2023.000000             2021.000000             5.0
# max                2023.000000             2023.000000             5.0
#
#         log_renewals  membership_duration_in_months
# count  436290.000000                  436290.000000
# mean        1.791759                      83.222084
# std         0.000000                      76.200631
# min         1.791759                       0.000000
# 25%         1.791759                      18.000000
# 50%         1.791759                      63.000000
# 75%         1.791759                     128.000000
# max         1.791759                     247.000000

# %%
df.describe(include='all')
# Out:
#         Patron Type Code Patron Type Definition  Total Checkouts  \
# count      436290.000000                 436290    436290.000000
# unique               NaN                     17              NaN
# top                  NaN                  Adult              NaN
# freq                 NaN                 274682              NaN
# mean            1.081295                    NaN       160.294843
# std             3.383103                    NaN       537.923680
# min             0.000000                    NaN         0.000000
# 25%             0.000000                    NaN         0.000000
# 50%             0.000000                    NaN         7.000000
# 75%             1.000000                    NaN        78.000000
# max           104.000000                    NaN     45380.000000
#
#         Total Renewals       Age Range Home Library Code  \
# count         436290.0          435378            436288
# unique             NaN              10                75
# top                NaN  25 to 34 years                 x
# freq               NaN           92669            141878
# mean               5.0             NaN               NaN
# std                0.0             NaN               NaN
# min                5.0             NaN               NaN
# 25%                5.0             NaN               NaN
# 50%                5.0             NaN               NaN
# 75%                5.0             NaN               NaN
# max                5.0             NaN               NaN
#
#        Home Library Definition Circulation Active Month  \
# count                   436260                   396777
# unique                      29                       12
# top                       Main                      Jul
# freq                    142000                   149494
# mean                       NaN                      NaN
# std                        NaN                      NaN
# min                        NaN                      NaN
# 25%                        NaN                      NaN
# 50%                        NaN                      NaN
# 75%                        NaN                      NaN
# max                        NaN                      NaN
#
#         Circulation Active Year Notice Preference Code  \
# count             396777.000000                 393301
# unique                      NaN                      1
# top                         NaN                      z
# freq                        NaN                 393301
# mean                2022.170698                    NaN
# std                    1.358145                    NaN
# min                 2004.000000                    NaN
# 25%                 2022.000000                    NaN
# 50%                 2023.000000                    NaN
# 75%                 2023.000000                    NaN
# max                 2023.000000                    NaN
#
#        Notice Preference Definition Provided Email Address  \
# count                        393301                 436290
# unique                            1                      2
# top                           Email                   True
# freq                         393301                 393301
# mean                            NaN                    NaN
# std                             NaN                    NaN
# min                             NaN                    NaN
# 25%                             NaN                    NaN
# 50%                             NaN                    NaN
# 75%                             NaN                    NaN
# max                             NaN                    NaN
#
#         Year Patron Registered Within San Francisco County  dummy_variable  \
# count            436290.000000                      435083        436290.0
# unique                     NaN                           1             NaN
# top                        NaN                       False             NaN
# freq                       NaN                      435083             NaN
# mean               2015.598327                         NaN             5.0
# std                   6.148953                         NaN             0.0
# min                2003.000000                         NaN             5.0
# 25%                2012.000000                         NaN             5.0
# 50%                2017.000000                         NaN             5.0
# 75%                2021.000000                         NaN             5.0
# max                2023.000000                         NaN             5.0
#
#        is_adult   log_renewals circ_a_month  membership_duration_in_months
# count    436290  436290.000000       396777                  436290.000000
# unique        2            NaN           12                            NaN
# top        True            NaN   1900-07-01                            NaN
# freq     274682            NaN       149494                            NaN
# mean        NaN       1.791759          NaN                      83.222084
# std         NaN       0.000000          NaN                      76.200631
# min         NaN       1.791759          NaN                       0.000000
# 25%         NaN       1.791759          NaN                      18.000000
# 50%         NaN       1.791759          NaN                      63.000000
# 75%         NaN       1.791759          NaN                     128.000000
# max         NaN       1.791759          NaN                     247.000000

# %%
df['Total Checkouts'].min()
# Out:
# 0

# %%
df['Total Checkouts'].max()
# Out:
# 45380

# %%
df['Total Checkouts'].between(2000, 2100).sum()
# Out:
# 539

# %%
df.shape
# Out:
# (436290, 19)
